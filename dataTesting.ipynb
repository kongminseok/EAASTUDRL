# %%
# common library
import pandas as pd
import numpy as np
import time
from stable_baselines.common.vec_env import DummyVecEnv

# preprocessor
from preprocessing.preprocessors import * # from folder.file import *
# config
from config.config import *
# model
from model.models import *
import os
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# C:\Users\kongminseok\anaconda3\envs\stockessay\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
# ...

# %%
data = pd.read_csv('SPY_done_data.csv',index_col=0)
data3 = pd.concat([data,data,data,data,data,
                   data,data,data,data,data,
                   data,data,data,data,data,
                   data,data,data,data,data,
                   data,data,data,data,data,
                   data,data,data,data,data])
data3.reset_index(drop=True, inplace=True)
display(data3)
data3.to_csv('SPY_done_data.csv')
# Out:
#        datadate  tic    adjcp     open      high     low       volume  \
# 0      20090102  SPY   92.960   90.440   93.4400   89.85  227563000.0
# 1      20090105  SPY   92.850   92.630   94.5533   91.89  240076500.0
# 2      20090106  SPY   93.470   93.640   94.4500   92.68  327996400.0
# 3      20090107  SPY   90.670   92.000   92.2600   90.20  280574700.0
# 4      20090108  SPY   91.042   90.160   91.0900   89.67  263579600.0
# ...         ...  ...      ...      ...       ...     ...          ...
# 86575  20200615  SPY  307.050  298.020  308.2800  296.74  134404100.0
# 86576  20200616  SPY  312.960  315.480  315.6400  307.67  137032900.0
# 86577  20200617  SPY  311.660  314.070  314.3900  310.86   82712980.0
# 86578  20200618  SPY  311.780  310.005  312.3000  309.51   80313450.0
# 86579  20200619  SPY  308.640  314.170  314.3800  306.53  134186100.0
#
#            macd        rsi         cci         adx  turbulence
# 0      0.000000   0.000000   66.666667  100.000000    0.000000
# ...

# %%
data1 = preprocess_data()
data1 = add_turbulence(data1)
display(data1)
# Out:
#       datadate  tic    adjcp     open      high     low       volume  \
# 0     20090102  SPY   92.960   90.440   93.4400   89.85  227563000.0
# 1     20090105  SPY   92.850   92.630   94.5533   91.89  240076500.0
# 2     20090106  SPY   93.470   93.640   94.4500   92.68  327996400.0
# 3     20090107  SPY   90.670   92.000   92.2600   90.20  280574700.0
# 4     20090108  SPY   91.042   90.160   91.0900   89.67  263579600.0
# ...        ...  ...      ...      ...       ...     ...          ...
# 2881  20200615  SPY  307.050  298.020  308.2800  296.74  134404100.0
# 2882  20200616  SPY  312.960  315.480  315.6400  307.67  137032900.0
# 2883  20200617  SPY  311.660  314.070  314.3900  310.86   82712980.0
# 2884  20200618  SPY  311.780  310.005  312.3000  309.51   80313450.0
# 2885  20200619  SPY  308.640  314.170  314.3800  306.53  134186100.0
#
#           macd        rsi         cci         adx  turbulence
# 0     0.000000   0.000000   66.666667  100.000000    0.000000
# ...

# %%
data1.to_csv('SPY_done_data.csv')

# %%
data2 = pd.read_csv('done_data.csv', index_col=0)
display(data2)
# Out:
#        datadate   tic       adjcp        open        high         low  \
# 0      20090102  AAPL   12.964286   12.268571   13.005714   12.165714
# 1      20090102   AXP   19.330000   18.570000   19.520000   18.400000
# 2      20090102    BA   45.250000   42.800000   45.560000   42.780000
# 3      20090102   CAT   46.910000   44.910000   46.980000   44.710000
# 4      20090102  CSCO   16.960000   16.410000   17.000000   16.250000
# ...         ...   ...         ...         ...         ...         ...
# 87775  20200817     V  199.430000  197.300000  200.460000  196.710000
# 87776  20200817    VZ   58.780000   58.730000   58.930000   58.545000
# 87777  20200817   WBA   41.175000   41.910000   41.969400   40.810000
# 87778  20200817   WMT  135.600000  134.350000  136.130000  133.850000
# 87779  20200817   XOM   42.640000   43.170000   43.170000   42.470000
#
#            volume      macd         rsi         cci         adx  turbulence
# ...

# %%
print(len(data2.datadate.unique()))
print(len(data2.tic.unique()))
print(2926*30)
# Out:
# 2926
# 30
# 87780

# %%
data1.cci.values.tolist()
# Out:
# [66.66666666666667,
#  66.66666666666667,
#  76.51116551472464,
#  -106.23559364487487,
#  -98.09258854219439,
#  -136.85175940956958,
#  -133.01401795795363,
#  -109.31192838224541,
#  -138.63487935250876,
#  -123.29051374710895,
#  -89.88107762228891,
#  -126.9818292679167,
#  -94.65622932956974,
#  -90.84510672642973,
#  -84.82664300781738,
#  -55.55803795556859,
#  -46.4661986576123,
#  7.494523181221433,
#  -25.0215342066927,
#  -64.27184758446461,
#  -83.17853243109077,
#  -58.48369085604404,
#  -47.25887785740342,
#  -74.25059002679477,
#  8.054870215963632,
#  23.806622367133862,
#  -40.90524906463958,
#  -59.11565406793382,
#  -69.07668416467622,
#  -58.182679424252875,
#  -122.9229004510515,
#  -158.4840346733969,
#  -171.19989738518368,
#  -214.23971468461139,
#  -239.38500475686502,
#  -190.71282500136996,
#  -163.73646123342317,
#  -145.59325446014628,
#  -181.44239425216355,
#  -209.16299497541524,
#  -199.00663734843695,
#  -156.33754527978724,
#  -166.92121108666623,
# ...
